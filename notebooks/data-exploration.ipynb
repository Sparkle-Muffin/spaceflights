# %%
# %load_ext kedro.ipython
# Out:
# [10/20/24 17:58:40] INFO     Using                                                                  ]8;id=31921;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=689164;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/home/pervitin/.local/lib/python3.10/site-packages/kedro/framework/pr
#                              oject/rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=842307;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=988716;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py#61\61]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=492228;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=58765;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py#63\63]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=533379;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=719023;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py#178\178]8;;\
#                              /media/veracrypt1/JAWNE/REPOZYTORIA/Machine_Learning/spaceflights.
#                              To set a different path, run '%reload_kedro <project_root>'
# [10/20/24 17:58:41] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=861848;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=733335;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro_telemetry/plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
# [10/20/24 17:58:42] INFO     Kedro project spaceflights                                             ]8;id=785636;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=240706;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py#144\144]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=970504;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=456288;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py#145\145]8;;\
#                              'pipelines'
# [10/20/24 17:58:43] INFO     Registered line magic 'run_viz'                                        ]8;id=206232;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=996169;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/ipython/__init__.py#151\151]8;;\

# %%
catalog
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {'companies': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('/media/veracrypt1/JAWNE/REPOZYTORIA/Machine_Learning/spaceflights/data/01_raw/companies.csv'), "
#               "protocol='file', load_args={}, save_args={'index': False})",
#  'reviews': "kedro_datasets.pandas.csv_dataset.CSVDataset(filepath=PurePosixPath('/media/veracrypt1/JAWNE/REPOZYTORIA/Machine_Learning/spaceflights/data/01_raw/reviews.csv'), "
#             "protocol='file', load_args={}, save_args={'index': False})",
#  'shuttles': "kedro_datasets.pandas.excel_dataset.ExcelDataset(filepath=PurePosixPath('/media/veracrypt1/JAWNE/REPOZYTORIA/Machine_Learning/spaceflights/data/01_raw/shuttles.xlsx'), "
#              "protocol='file', load_args={'engine': 'openpyxl'}, "
#              "save_args={'index': False}, writer_args={'engine': 'openpyxl'})",
#  'preprocessed_companies': "kedro_datasets.pandas.parquet_dataset.ParquetDataset(filepath=PurePosixPath('/media/veracrypt1/JAWNE/REPOZYTORIA/Machine_Learning/spaceflights/data/02_intermediate/preprocessed_companies.pq'), "
#                            "protocol='file', load_args={}, save_args={})",
#  'preprocessed_shuttles': "kedro_datasets.pandas.parquet_dataset.ParquetDataset(filepath=PurePosixPath('/media/veracrypt1/JAWNE/REPOZYTORIA/Machine_Learning/spaceflights/data/02_intermediate/preprocessed_shuttles.pq'), "
#                           "protocol='file', load_args={}, save_args={})",
#  'parameters': "kedro.io.memory_dataset.MemoryDataset(data='<dict>')"}

# %%
companies = catalog.load("companies")
companies.head()
# Out:
# [10/20/24 17:59:37] INFO     Loading data from companies (CSVDataset)...                        ]8;id=151496;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=108339;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id company_rating       company_location  total_fleet_count  \
# 0  35029           100%                   Niue                4.0
# 1  30292            67%               Anguilla                6.0
# 2  19032            67%     Russian Federation                4.0
# 3   8238            91%               Barbados               15.0
# 4  30342            NaN  Sao Tome and Principe                2.0
#
#   iata_approved
# 0             f
# 1             f
# 2             f
# 3             t
# 4             t

# %%
import pandas as pd

# %%
def _is_true(x: pd.Series) -> pd.Series:
    return x == "t"

# %%
type(companies)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <class 'pandas.core.frame.DataFrame'>

# %%
companies["iata_approved"] = _is_true(companies["iata_approved"])

# %%
companies.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id company_rating       company_location  total_fleet_count  \
# 0  35029           100%                   Niue                4.0
# 1  30292            67%               Anguilla                6.0
# 2  19032            67%     Russian Federation                4.0
# 3   8238            91%               Barbados               15.0
# 4  30342            NaN  Sao Tome and Principe                2.0
#
#    iata_approved
# 0          False
# 1          False
# 2          False
# 3           True
# 4           True

# %%
companies.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# id                     int64
# company_rating        object
# company_location      object
# total_fleet_count    float64
# iata_approved           bool
# dtype: object

# %%
def _parse_percentage(x: pd.Series) -> pd.Series:
    return x.str.replace("%", "").astype("float")

# %%
companies["company_rating"] = _parse_percentage(companies["company_rating"])

# %%
companies.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id  company_rating       company_location  total_fleet_count  \
# 0  35029           100.0                   Niue                4.0
# 1  30292            67.0               Anguilla                6.0
# 2  19032            67.0     Russian Federation                4.0
# 3   8238            91.0               Barbados               15.0
# 4  30342             NaN  Sao Tome and Principe                2.0
#
#    iata_approved
# 0          False
# 1          False
# 2          False
# 3           True
# 4           True

# %%
companies.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# id                     int64
# company_rating       float64
# company_location      object
# total_fleet_count    float64
# iata_approved           bool
# dtype: object

# %%
shuttles = catalog.load("shuttles")
# Out:
# [10/20/24 18:00:45] INFO     Loading data from shuttles (ExcelDataset)...                       ]8;id=223925;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=821972;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %%
shuttles.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561                   Niue      Type V5     Quantum  ThetaBase Services
# 1  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 2  57015     Russian Federation      Type V5     Quantum  ThetaBase Services
# 3  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 4  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew d_check_complete  \
# 0      1.0                   2              strict   1.0                f
# 1      1.0                   2              strict   1.0                t
# 2      1.0                   2            moderate   0.0                f
# 3      3.0                   6              strict   3.0                f
# 4      2.0                   4              strict   2.0                f
#
#   moon_clearance_complete     price  company_id
# 0                       f  $1,325.0       35029
# 1                       f  $1,780.0       30292
# 2                       f  $1,715.0       19032
# 3                       f  $4,770.0        8238
# 4                       f  $2,820.0       30342

# %%
shuttles.iloc[:, 5:]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        engines  passenger_capacity cancellation_policy  crew d_check_complete  \
# 0          1.0                   2              strict   1.0                f
# 1          1.0                   2              strict   1.0                t
# 2          1.0                   2            moderate   0.0                f
# 3          3.0                   6              strict   3.0                f
# 4          2.0                   4              strict   2.0                f
# ...        ...                 ...                 ...   ...              ...
# 77091      2.0                   4            flexible   2.0                t
# 77092      1.0                   1            flexible   1.0                t
# 77093      0.0                   2            flexible   1.0                t
# 77094      1.0                   2            flexible   1.0                t
# 77095      0.0                   2            moderate   2.0                t
#
#       moon_clearance_complete     price  company_id
# 0                           f  $1,325.0       35029
# 1                           f  $1,780.0       30292
# 2                           f  $1,715.0       19032
# 3                           f  $4,770.0        8238
# 4                           f  $2,820.0       30342
# ...                       ...       ...         ...
# 77091                       f  $4,107.0        6654
# 77092                       f  $1,169.0        8000
# 77093                       f  $1,910.0       14296
# 77094                       f  $2,170.0       27363
# 77095                       f  $1,455.0       12542
#
# [77096 rows x 8 columns]

# %%
shuttles.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# id                           int64
# shuttle_location            object
# shuttle_type                object
# engine_type                 object
# engine_vendor               object
# engines                    float64
# passenger_capacity           int64
# cancellation_policy         object
# crew                       float64
# d_check_complete            object
# moon_clearance_complete     object
# price                       object
# company_id                   int64
# dtype: object

# %%
shuttles["d_check_complete"] = _is_true(shuttles["d_check_complete"])
shuttles["moon_clearance_complete"] = _is_true(shuttles["moon_clearance_complete"])

# %%
def _parse_money(x:pd.Series) -> pd.Series:
    return x.str.replace("$", "").str.replace(",", "").astype(float)

# %%
shuttles["price"] = _parse_money(shuttles["price"])

# %%
shuttles.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# id                           int64
# shuttle_location            object
# shuttle_type                object
# engine_type                 object
# engine_vendor               object
# engines                    float64
# passenger_capacity           int64
# cancellation_policy         object
# crew                       float64
# d_check_complete              bool
# moon_clearance_complete       bool
# price                      float64
# company_id                   int64
# dtype: object

# %%
catalog.load("reviews")
# Out:
# [10/20/24 13:06:16] INFO     Loading data from reviews (CSVDataset)...                          ]8;id=710540;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=354518;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#        shuttle_id  review_scores_rating  review_scores_comfort  \
# 0           63561                  97.0                   10.0
# 1           36260                  90.0                    8.0
# 2           57015                  95.0                    9.0
# 3           14035                  93.0                   10.0
# 4           10036                  98.0                   10.0
# ...           ...                   ...                    ...
# 77091        4368                   NaN                    NaN
# 77092        2983                   NaN                    NaN
# 77093       69684                   NaN                    NaN
# 77094       21738                   NaN                    NaN
# 77095       72645                   NaN                    NaN
#
#        review_scores_amenities  review_scores_trip  review_scores_crew  \
# 0                          9.0                10.0                10.0
# 1                          9.0                10.0                 9.0
# 2                         10.0                 9.0                10.0
# 3                          9.0                 9.0                 9.0
# 4                         10.0                10.0                10.0
# ...                        ...                 ...                 ...
# 77091                      NaN                 NaN                 NaN
# 77092                      NaN                 NaN                 NaN
# 77093                      NaN                 NaN                 NaN
# 77094                      NaN                 NaN                 NaN
# 77095                      NaN                 NaN                 NaN
#
#        review_scores_location  review_scores_price  number_of_reviews  \
# 0                         9.0                 10.0                133
# 1                         9.0                  9.0                  3
# 2                         9.0                  9.0                 14
# 3                        10.0                  9.0                 39
# 4                         9.0                  9.0                 92
# ...                       ...                  ...                ...
# 77091                     NaN                  NaN                  0
# 77092                     NaN                  NaN                  0
# 77093                     NaN                  NaN                  0
# 77094                     NaN                  NaN                  0
# 77095                     NaN                  NaN                  0
#
#        reviews_per_month
# 0                   1.65
# 1                   0.09
# 2                   0.14
# 3                   0.42
# 4                   0.94
# ...                  ...
# 77091                NaN
# 77092                NaN
# 77093                NaN
# 77094                NaN
# 77095                NaN
#
# [77096 rows x 10 columns]

# %%
shuttles.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561                   Niue      Type V5     Quantum  ThetaBase Services
# 1  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 2  57015     Russian Federation      Type V5     Quantum  ThetaBase Services
# 3  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 4  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      1.0                   2              strict   1.0             False
# 1      1.0                   2              strict   1.0              True
# 2      1.0                   2            moderate   0.0             False
# 3      3.0                   6              strict   3.0             False
# 4      2.0                   4              strict   2.0             False
#
#    moon_clearance_complete   price  company_id
# 0                    False  1325.0       35029
# 1                    False  1780.0       30292
# 2                    False  1715.0       19032
# 3                    False  4770.0        8238
# 4                    False  2820.0       30342

# %%
reviews = catalog.load("reviews")
# Out:
# [10/20/24 18:03:35] INFO     Loading data from reviews (CSVDataset)...                          ]8;id=26399;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=683983;file:///home/pervitin/.local/lib/python3.10/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %%
reviews.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    shuttle_id  review_scores_rating  review_scores_comfort  \
# 0       63561                  97.0                   10.0
# 1       36260                  90.0                    8.0
# 2       57015                  95.0                    9.0
# 3       14035                  93.0                   10.0
# 4       10036                  98.0                   10.0
#
#    review_scores_amenities  review_scores_trip  review_scores_crew  \
# 0                      9.0                10.0                10.0
# 1                      9.0                10.0                 9.0
# 2                     10.0                 9.0                10.0
# 3                      9.0                 9.0                 9.0
# 4                     10.0                10.0                10.0
#
#    review_scores_location  review_scores_price  number_of_reviews  \
# 0                     9.0                 10.0                133
# 1                     9.0                  9.0                  3
# 2                     9.0                  9.0                 14
# 3                    10.0                  9.0                 39
# 4                     9.0                  9.0                 92
#
#    reviews_per_month
# 0               1.65
# 1               0.09
# 2               0.14
# 3               0.42
# 4               0.94

# %%
rated_shuttles = shuttles.merge(reviews, left_on="id", right_on="shuttle_id")
rated_shuttles.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561                   Niue      Type V5     Quantum  ThetaBase Services
# 1  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 2  57015     Russian Federation      Type V5     Quantum  ThetaBase Services
# 3  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 4  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      1.0                   2              strict   1.0             False
# 1      1.0                   2              strict   1.0              True
# 2      1.0                   2            moderate   0.0             False
# 3      3.0                   6              strict   3.0             False
# 4      2.0                   4              strict   2.0             False
#
#    ...  shuttle_id  review_scores_rating  review_scores_comfort  \
# 0  ...       63561                  97.0                   10.0
# 1  ...       36260                  90.0                    8.0
# 2  ...       57015                  95.0                    9.0
# 3  ...       14035                  93.0                   10.0
# 4  ...       10036                  98.0                   10.0
#
#    review_scores_amenities  review_scores_trip  review_scores_crew  \
# 0                      9.0                10.0                10.0
# 1                      9.0                10.0                 9.0
# 2                     10.0                 9.0                10.0
# 3                      9.0                 9.0                 9.0
# 4                     10.0                10.0                10.0
#
#    review_scores_location  review_scores_price  number_of_reviews  \
# 0                     9.0                 10.0                133
# 1                     9.0                  9.0                  3
# 2                     9.0                  9.0                 14
# 3                    10.0                  9.0                 39
# 4                     9.0                  9.0                 92
#
#    reviews_per_month
# 0               1.65
# 1               0.09
# 2               0.14
# 3               0.42
# 4               0.94
#
# [5 rows x 23 columns]

# %%
rated_shuttles.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['id', 'shuttle_location', 'shuttle_type', 'engine_type',
#        'engine_vendor', 'engines', 'passenger_capacity', 'cancellation_policy',
#        'crew', 'd_check_complete', 'moon_clearance_complete', 'price',
#        'company_id', 'shuttle_id', 'review_scores_rating',
#        'review_scores_comfort', 'review_scores_amenities',
#        'review_scores_trip', 'review_scores_crew', 'review_scores_location',
#        'review_scores_price', 'number_of_reviews', 'reviews_per_month'],
#       dtype='object')

# %%
model_input_table = rated_shuttles.merge(companies, left_on="shuttle_id", right_on="id")
model_input_table.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     id_x       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 1  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 2  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
# 3  45163  Sao Tome and Principe      Type V5      Plasma  ThetaBase Services
# 4  45163  Sao Tome and Principe      Type V5      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew  d_check_complete  \
# 0      1.0                   2              strict   1.0              True
# 1      3.0                   6              strict   3.0             False
# 2      2.0                   4              strict   2.0             False
# 3      2.0                   4            moderate   2.0             False
# 4      2.0                   4            moderate   2.0             False
#
#    ...  review_scores_crew  review_scores_location  review_scores_price  \
# 0  ...                 9.0                     9.0                  9.0
# 1  ...                 9.0                    10.0                  9.0
# 2  ...                10.0                     9.0                  9.0
# 3  ...                 9.0                     9.0                  9.0
# 4  ...                 9.0                     9.0                  9.0
#
#    number_of_reviews  reviews_per_month   id_y  company_rating  \
# 0                  3               0.09  36260           100.0
# 1                 39               0.42  14035            94.0
# 2                 92               0.94  10036             NaN
# 3                 26               0.77  45163           100.0
# 4                 26               0.77  45163           100.0
#
#    company_location  total_fleet_count  iata_approved
# 0  Papua New Guinea                1.0          False
# 1         Greenland                1.0          False
# 2               NaN                2.0           True
# 3             Chile                2.0           True
# 4             Chile                2.0           True
#
# [5 rows x 28 columns]

# %%
model_input_table.dropna()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#         id_x       shuttle_location shuttle_type engine_type  \
# 0      36260               Anguilla      Type V5     Quantum
# 1      14035               Barbados      Type V5      Plasma
# 3      45163  Sao Tome and Principe      Type V5      Plasma
# 4      45163  Sao Tome and Principe      Type V5      Plasma
# 5      23389             Micronesia      Type V5     Quantum
# ...      ...                    ...          ...         ...
# 75995  40528                 Rwanda      Type V5      Plasma
# 76032  17775                Estonia      Type F5     Quantum
# 76343  48664               Pakistan      Type V5     Quantum
# 76344  48664               Pakistan      Type V5     Quantum
# 76463  40163                 Rwanda      Type G0      Plasma
#
#             engine_vendor  engines  passenger_capacity cancellation_policy  \
# 0      ThetaBase Services      1.0                   2              strict
# 1      ThetaBase Services      3.0                   6              strict
# 3      ThetaBase Services      2.0                   4            moderate
# 4      ThetaBase Services      2.0                   4            moderate
# 5      ThetaBase Services      1.0                   1            moderate
# ...                   ...      ...                 ...                 ...
# 75995  ThetaBase Services      1.0                   6              strict
# 76032  ThetaBase Services      1.0                   2            flexible
# 76343  ThetaBase Services      1.0                   2            flexible
# 76344  ThetaBase Services      1.0                   2            flexible
# 76463  ThetaBase Services      4.0                   8              strict
#
#        crew  d_check_complete  ...  review_scores_crew  \
# 0       1.0              True  ...                 9.0
# 1       3.0             False  ...                 9.0
# 3       2.0             False  ...                 9.0
# 4       2.0             False  ...                 9.0
# 5       1.0             False  ...                 8.0
# ...     ...               ...  ...                 ...
# 75995   1.0              True  ...                10.0
# 76032   1.0             False  ...                10.0
# 76343   1.0              True  ...                10.0
# 76344   1.0              True  ...                10.0
# 76463   4.0             False  ...                10.0
#
#        review_scores_location  review_scores_price  number_of_reviews  \
# 0                         9.0                  9.0                  3
# 1                        10.0                  9.0                 39
# 3                         9.0                  9.0                 26
# 4                         9.0                  9.0                 26
# 5                         9.0                  9.0                  5
# ...                       ...                  ...                ...
# 75995                    10.0                 10.0                  1
# 76032                    10.0                 10.0                  1
# 76343                    10.0                 10.0                  1
# 76344                    10.0                 10.0                  1
# 76463                    10.0                 10.0                  2
#
#        reviews_per_month   id_y  company_rating  company_location  \
# 0                   0.09  36260           100.0  Papua New Guinea
# 1                   0.42  14035            94.0         Greenland
# 3                   0.77  45163           100.0             Chile
# 4                   0.77  45163           100.0             Chile
# 5                   0.05  23389           100.0              Niue
# ...                  ...    ...             ...               ...
# 75995               1.00  40528           100.0            Guinea
# 76032               1.00  17775           100.0      Turkmenistan
# 76343               1.00  48664           100.0          Maldives
# 76344               1.00  48664           100.0          Maldives
# 76463               2.00  40163           100.0  Marshall Islands
#
#        total_fleet_count  iata_approved
# 0                    1.0          False
# 1                    1.0          False
# 3                    2.0           True
# 4                    2.0           True
# 5                    1.0          False
# ...                  ...            ...
# 75995                1.0          False
# 76032                1.0          False
# 76343                2.0          False
# 76344                2.0          False
# 76463                1.0          False
#
# [26935 rows x 28 columns]
